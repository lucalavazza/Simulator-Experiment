out_stat_dcbo = [-2.1406726710027244, -4.289708387314894, -6.402739210447878, -8.551774926760046, -10.62931378325274, -12.74863387134371, -14.809161618789673, -16.958591958124636, -19.10749132654685, -21.105087286577852, -23.248905262026717, -25.324776340224805, -27.47126652293971, -29.589478704237937, -31.674212606561532, -33.82561111416171, -35.80671805983608, -37.685397159562754, -39.82483438730088, -41.67008831610044]
out_nonstat_dcbo = [4.363114978443591, -8.375441853471763, 12.544677558356105, -12.39665394050144, 12.392152359830352, -12.381167456060155, 12.521766623708878, -12.6662319774407, 12.732331069259496, -12.652204169150108, 13.039858490332936, -13.40950445955676, 13.967398787476585, -14.472855716767604, 14.935171700941703, -15.318069615213819, 15.478610982643737, -15.606911017640945, 15.800306836766055, -15.92921869882818]
out_multi_dcbo = [-2.2274324349364756, -5.138700156444859, -8.023343478373162, -10.943855345590695, -13.865283851874391, -16.78593206698188, -19.70762963749561, -22.619914807293654, -25.529048209792347, -28.447491552289716, -31.35276395982506, -34.27341217493255, -37.055205209566246, -39.9976180241928, -42.941188009033745, -45.8836008236603, -48.82689987535858, -51.47078329957932, -54.38815594612728, -57.142733122201044]
out_ind_dcbo = [-1.1602582842845497, -2.15817977708077, -4.033246276609876, -4.981722076211957, -6.987521456392697, -7.496904562361344, -8.56963437615796, -9.460454444063233, -10.214667025372869, -10.952333511212622, -11.764326377995474, -12.963884963601936, -13.485768076647668, -14.728535026717907, -15.24670306627182, -15.773329644813948, -16.777732645032305, -18.516039424597174, -19.185224289410318, -21.174459411377203]

# %% [markdown]
# # $\pi$BO and DC-$\pi$BO

# %% [markdown]
# ### $\pi$BO's predictions

# %% [markdown]
# ### DC-$\pi$BO's predictions

# %% [markdown]
# ### Comparison between the optima and the predicted values

# %%
plt.plot(t, y_stat, '-ro', label = 'TRUE_STAT')
plt.plot(t, out_stat_bo, '--rx', label = 'OUT_STAT_BO')
plt.plot(t, out_stat_dcbo, '--rv', label = 'OUT_STAT_DCBO')
# plt.plot(t, out_stat_pibo, '--g.', label = 'OUT_STAT_PIBO')
# plt.plot(t, out_stat_dcpibo, '--b.', label = 'OUT_STAT_DCPIBO')
plt.xlabel('t')
plt.ylabel('x')
plt.grid()
plt.legend()
plt.savefig('./Pictures/OPTIMUM_BEHAVIOUR-STAT')
plt.show()

# %%
plt.plot(t, y_nonstat, '-bo', label = 'TRUE_NONSTAT')
plt.plot(t, out_nonstat_bo, '--bx', label = 'OUT_NONSTAT_BO')
plt.plot(t, out_nonstat_dcbo, '--bv', label = 'OUT_NONSTAT_DCBO')
plt.xlabel('t')
plt.ylabel('x')
plt.grid()
plt.legend()
plt.savefig('./Pictures/OPTIMUM_BEHAVIOUR-NONSTAT')
plt.show()

# %%
plt.plot(t, y_multi, '-go', label = 'TRUE_MULTI')
plt.plot(t, out_multi_bo, '--gx', label = 'OUT_MULTI_BO')
plt.plot(t, out_multi_dcbo, '--gv', label = 'OUT_MULTI_DCBO')
plt.xlabel('t')
plt.ylabel('x')
plt.grid()
plt.legend()
plt.savefig('./Pictures/OPTIMUM_BEHAVIOUR-MULTI')
plt.show()

# %%
plt.plot(t, y_ind, '-ko', label = 'TRUE_IND')
plt.plot(t, out_ind_bo, '--kx', label = 'OUT_IND_BO')
plt.plot(t, out_ind_dcbo, '--kv', label = 'OUT_IND_DCBO')
plt.xlabel('t')
plt.ylabel('x')
plt.grid()
plt.legend()
plt.savefig('./Pictures/OPTIMUM_BEHAVIOUR-IND')
plt.show()
